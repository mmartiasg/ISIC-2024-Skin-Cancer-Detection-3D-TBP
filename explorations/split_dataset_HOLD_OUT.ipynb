# %%
from prototypes.deeplearning.dataloader.IsicDataLoader import IsicDataLoaderFolders, over_under_sample, load_val_images, create_folds, AugmentationWrapper
from prototypes.utility.data import ProjectConfiguration
import pandas as pd

# %%
config = ProjectConfiguration("../config.json")

# %%
config.get_keys()
# Out:
# dict_keys(['DATASET_PATH', 'TRAIN_IMAGES_PATH', 'TRAIN_METADATA', 'TEST_METADATA', 'SAMPLE_SUBMISSION', 'IMAGE_WIDTH', 'IMAGE_HEIGHT', 'TARGET_COLUMNS', 'VECTORS_PATH', 'BATCH_SIZE', 'K_FOLDS', 'NUM_CLASSES', 'ALPHA', 'TRAIN_DEVICE', 'USE_SAMPLER', 'TRAIN_SAMPLE_SIZE', 'VAL_SAMPLE_SIZE', 'TRAIN_SPLIT', 'NUM_EPOCHS', 'NUM_WORKERS', 'PREFETCH_FACTOR', 'MODEL', 'DROPOUT_LAST_LAYER', 'CLASS_BALANCE_PERCENTAGE', 'ENABLED_EXPONENTIAL_LR', 'USING_MIXUP', 'TOTAL_TRAIN_SAMPLES', 'PER_SAMPLE_AUGMENTATION', 'METADATA_COLUMNS', 'LEARNING_RATE', 'TOLERANCE_EARLY_STOPPING', 'SAMPLE_PERCENTAGE', 'HYPER_PARAMETERS_PATH', 'VERSION'])

# %%
metadata_df = pd.read_csv(config.get_value("TRAIN_METADATA"), engine="python")
columns = config.get_value("METADATA_COLUMNS").split("\t")

isic_id, metadata_array, labels = metadata_df["isic_id"].values, metadata_df[columns].values, metadata_df[
    "target"].values

# %%
folds_config_dict = create_folds(isic_id=isic_id, metadata=metadata_array, labels=labels, config=config)

# %%
folds_config_dict
# Out:
# {'1': {'train': {'isic_id': array(['ISIC_0015670', 'ISIC_0015845', 'ISIC_0015864', ...,
#           'ISIC_9999960', 'ISIC_9999964', 'ISIC_9999967'], dtype=object),
#    'metadata': array([[ 2.02444223e+01,  1.62619752e+01,  2.69224474e+01, ...,
#            -1.82703552e+02,  6.13493652e+02, -4.24279480e+01],
#           [ 3.17125700e+01,  2.53647400e+01,  2.63310000e+01, ...,
#            -7.83081100e-02,  1.57568700e+03,  5.71745000e+01],
#           [ 2.25758300e+01,  1.71281700e+01,  3.79704600e+01, ...,
#             1.23649700e+02,  1.47201000e+03,  2.32908900e+02],
#           ...,
#           [ 1.73325667e+01,  1.23643974e+01,  2.98453261e+01, ...,
#             5.46222458e+01,  1.06526367e+03, -1.06833740e+02],
#           [ 2.22885700e+01,  9.56472100e+00,  2.84312000e+01, ...,
#            -9.86155700e+00,  8.77527000e+02, -7.69821200e+01],
#           [ 1.67929000e+01,  1.14347300e+01,  2.14572200e+01, ...,
#            -2.58872300e+02,  1.48606200e+02,  1.07710600e+02]]),
#    'target': array([0, 0, 0, ..., 0, 0, 0])},
#   'val': {'isic_id': array(['ISIC_0035502', 'ISIC_0051812', 'ISIC_0052042', ...,
#           'ISIC_9999665', 'ISIC_9999678', 'ISIC_9999762'], dtype=object),
#           'ISIC_9999960', 'ISIC_9999964', 'ISIC_9999967'], dtype=object),
#    'metadata': array([[ 2.02444223e+01,  1.62619752e+01,  2.69224474e+01, ...,
#            -1.82703552e+02,  6.13493652e+02, -4.24279480e+01],
#           [ 3.17125700e+01,  2.53647400e+01,  2.63310000e+01, ...,
#            -7.83081100e-02,  1.57568700e+03,  5.71745000e+01],
#           [ 2.25758300e+01,  1.71281700e+01,  3.79704600e+01, ...,
#             1.23649700e+02,  1.47201000e+03,  2.32908900e+02],
#           ...,
#           [ 1.73325667e+01,  1.23643974e+01,  2.98453261e+01, ...,
#             5.46222458e+01,  1.06526367e+03, -1.06833740e+02],
#           [ 2.22885700e+01,  9.56472100e+00,  2.84312000e+01, ...,
#            -9.86155700e+00,  8.77527000e+02, -7.69821200e+01],
#           [ 1.67929000e+01,  1.14347300e+01,  2.14572200e+01, ...,
#            -2.58872300e+02,  1.48606200e+02,  1.07710600e+02]]),
#    'target': array([0, 0, 0, ..., 0, 0, 0])},
#   'val': {'isic_id': array(['ISIC_0073665', 'ISIC_0073694', 'ISIC_0075726', ...,
#           'ISIC_9997974', 'ISIC_9999386', 'ISIC_9999779'], dtype=object),
#    'metadata': array([[  13.44119   ,    7.733225  ,   25.07299   , ..., -220.1425    ,
#             209.046     ,  110.7331    ],
#           [  21.04827401,   16.64249399,   26.82429532, ..., -218.90209961,
#             395.3727417 ,  119.33190918],
#           [  16.35513894,   15.6389425 ,   22.01105944, ...,  453.39764404,
#            1282.6159668 ,   48.36676025],
#           ...,
#           [  20.20573   ,   14.1196    ,   35.31162   , ...,  -54.97266   ,
#            1290.875     ,  123.7299    ],
#           [  22.71122375,   16.45014421,   39.50601963, ...,    7.39274263,
#            1317.32836914,  166.43963623],
#           [  19.44128741,   14.90205504,   28.40211793, ..., -231.63555908,
#             306.80505371,  113.07174683]]),
#    'target': array([0, 0, 0, ..., 0, 0, 0])}},
#  '4': {'train': {'isic_id': array(['ISIC_0015670', 'ISIC_0015845', 'ISIC_0015864', ...,
#           'ISIC_9999960', 'ISIC_9999964', 'ISIC_9999967'], dtype=object),
#    'metadata': array([[ 2.02444223e+01,  1.62619752e+01,  2.69224474e+01, ...,
#            -1.82703552e+02,  6.13493652e+02, -4.24279480e+01],
#           [ 3.17125700e+01,  2.53647400e+01,  2.63310000e+01, ...,
#            -7.83081100e-02,  1.57568700e+03,  5.71745000e+01],
#           [ 2.25758300e+01,  1.71281700e+01,  3.79704600e+01, ...,
#             1.23649700e+02,  1.47201000e+03,  2.32908900e+02],
#           ...,
#           [ 1.73325667e+01,  1.23643974e+01,  2.98453261e+01, ...,
#             5.46222458e+01,  1.06526367e+03, -1.06833740e+02],
#           [ 2.22885700e+01,  9.56472100e+00,  2.84312000e+01, ...,
#            -9.86155700e+00,  8.77527000e+02, -7.69821200e+01],
#           [ 1.67929000e+01,  1.14347300e+01,  2.14572200e+01, ...,
#            1056.274     ,  141.9261    ]]),
#    'target': array([0, 0, 0, ..., 0, 0, 0])}},
#  '6': {'train': {'isic_id': array(['ISIC_0015670', 'ISIC_0015845', 'ISIC_0015902', ...,
#           'ISIC_9999937', 'ISIC_9999964', 'ISIC_9999967'], dtype=object),
#    'metadata': array([[ 2.02444223e+01,  1.62619752e+01,  2.69224474e+01, ...,
#            -1.82703552e+02,  6.13493652e+02, -4.24279480e+01],
#           [ 3.17125700e+01,  2.53647400e+01,  2.63310000e+01, ...,
#            -7.83081100e-02,  1.57568700e+03,  5.71745000e+01],
#           [ 1.42423289e+01,  1.21647573e+01,  2.14481443e+01, ...,
#            -1.41024780e+02,  1.44218579e+03,  5.83598022e+01],
#           ...,
#           [ 2.25743346e+01,  1.49446663e+01,  2.76632587e+01, ...,
#             1.47187256e+02,  1.18231750e+03,  1.22652588e+02],
#           [ 2.22885700e+01,  9.56472100e+00,  2.84312000e+01, ...,
#            -9.86155700e+00,  8.77527000e+02, -7.69821200e+01],
#           [ 1.67929000e+01,  1.14347300e+01,  2.14572200e+01, ...,
#            -2.58872300e+02,  1.48606200e+02,  1.07710600e+02]]),
#    'target': array([0, 0, 0, ..., 0, 0, 0])},
#   'val': {'isic_id': array(['ISIC_0015864', 'ISIC_0024200', 'ISIC_0052205', ...,
#           'ISIC_9999411', 'ISIC_9999951', 'ISIC_9999960'], dtype=object),
#    'metadata': array([[  22.57583   ,   17.12817   ,   37.97046   , ...,  123.6497    ,
#            1472.01      ,  232.9089    ],
#           [  24.72552   ,   20.05747   ,   26.4649    , ...,  -72.31564   ,
#            1488.72      ,   21.42896   ],
#           [  19.02347594,   16.08660214,   30.23575305, ...,  406.64599609,
#            1168.79248047,  -20.48028564],
#           ...,
#           [  20.42011764,   13.8026258 ,   24.87580363, ...,   11.91695595,
#            1216.97241211,  111.36273193],
#           [  19.97764   ,   16.02687   ,   34.15884   , ...,   52.34974   ,
#            1393.187     ,  127.2617    ],
#           [  17.33256672,   12.36439742,   29.84532611, ...,   54.62224579,
#            1065.26367188, -106.83374023]]),
#    'target': array([0, 0, 0, ..., 0, 0, 0])}},
#  '7': {'train': {'isic_id': array(['ISIC_0015670', 'ISIC_0015845', 'ISIC_0015864', ...,
#           'ISIC_9999960', 'ISIC_9999964', 'ISIC_9999967'], dtype=object),
#    'metadata': array([[ 2.02444223e+01,  1.62619752e+01,  2.69224474e+01, ...,
#            -1.82703552e+02,  6.13493652e+02, -4.24279480e+01],
#           [ 3.17125700e+01,  2.53647400e+01,  2.63310000e+01, ...,
#            -7.83081100e-02,  1.57568700e+03,  5.71745000e+01],
#           [ 2.25758300e+01,  1.71281700e+01,  3.79704600e+01, ...,
#             1.23649700e+02,  1.47201000e+03,  2.32908900e+02],
#           ...,
#           [ 1.73325667e+01,  1.23643974e+01,  2.98453261e+01, ...,
#             5.46222458e+01,  1.06526367e+03, -1.06833740e+02],
#           [ 2.22885700e+01,  9.56472100e+00,  2.84312000e+01, ...,
#            -9.86155700e+00,  8.77527000e+02, -7.69821200e+01],
#           [ 1.67929000e+01,  1.14347300e+01,  2.14572200e+01, ...,
#            -2.58872300e+02,  1.48606200e+02,  1.07710600e+02]]),
#    'target': array([0, 0, 0, ..., 0, 0, 0])},
#   'val': {'isic_id': array(['ISIC_0051958', 'ISIC_0052026', 'ISIC_0052109', ...,
#           'ISIC_9999282', 'ISIC_9999477', 'ISIC_9999539'], dtype=object),
#    'metadata': array([[  12.91218   ,   10.23901   ,   26.99213   , ...,  -23.97464   ,
#            1213.993     ,  187.0327    ],
#           [  19.4104    ,   13.54244   ,   25.05215   , ..., -278.6346    ,
#             243.7309    ,   26.31647   ],
#           [  18.35989464,   14.1983938 ,   19.51653785, ...,  159.91552734,
#            1119.33789062,  132.39743042],
#           ...,
#           [  18.00484567,   14.75585963,   28.02748395, ...,  118.199646  ,
#             591.52307129,  -24.60290527],
#           [  17.66533   ,   12.1841    ,   33.26597   , ...,  129.353     ,
#            1241.044     ,  115.9584    ],
#           [  15.83357605,   12.90871237,   33.63611208, ...,  -45.61114502,
#            1009.24084473,  -57.57012939]]),
#    'target': array([0, 0, 0, ..., 0, 0, 0])}},
#  '8': {'train': {'isic_id': array(['ISIC_0015864', 'ISIC_0015902', 'ISIC_0024200', ...,
#           'ISIC_9999960', 'ISIC_9999964', 'ISIC_9999967'], dtype=object),
#    'metadata': array([[  22.57583   ,   17.12817   ,   37.97046   , ...,  123.6497    ,
#            1472.01      ,  232.9089    ],
#           [  14.24232888,   12.16475727,   21.44814427, ..., -141.02478027,
#            1442.18579102,   58.35980225],
#           [  24.72552   ,   20.05747   ,   26.4649    , ...,  -72.31564   ,
#            1488.72      ,   21.42896   ],
#           ...,
#           [  17.33256672,   12.36439742,   29.84532611, ...,   54.62224579,
#            1065.26367188, -106.83374023],
#           [  22.28857   ,    9.564721  ,   28.4312    , ...,   -9.861557  ,
#             877.527     ,  -76.98212   ],
#           [  16.7929    ,   11.43473   ,   21.45722   , ..., -258.8723    ,
#             148.6062    ,  107.7106    ]]),
#    'target': array([0, 0, 0, ..., 0, 0, 0])},
#   'val': {'isic_id': array(['ISIC_0015670', 'ISIC_0015845', 'ISIC_0051665', ...,
#           'ISIC_9999045', 'ISIC_9999497', 'ISIC_9999508'], dtype=object),
#    'metadata': array([[ 2.02444223e+01,  1.62619752e+01,  2.69224474e+01, ...,
#            -1.82703552e+02,  6.13493652e+02, -4.24279480e+01],
#           [ 3.17125700e+01,  2.53647400e+01,  2.63310000e+01, ...,
#            -7.83081100e-02,  1.57568700e+03,  5.71745000e+01],
#           [ 2.01026100e+01,  1.60048100e+01,  2.48256300e+01, ...,
#            -8.09270900e+01,  1.53512700e+03,  1.61490800e+02],
#           ...,
#           [ 2.32146630e+01,  1.97239507e+01,  2.73791591e+01, ...,
#            -1.05800301e+02,  1.45394519e+03,  1.35489075e+02],
#           [ 2.45869153e+01,  1.59998541e+01,  2.95479375e+01, ...,
#             1.86945251e+02,  7.62729919e+02,  1.03439453e+02],
#           [ 2.28967101e+01,  1.62173716e+01,  3.51752991e+01, ...,
#             2.64832794e+02,  2.85631104e+02,  1.24361267e+02]]),
#    'target': array([0, 0, 0, ..., 0, 0, 0])}},
#  '9': {'train': {'isic_id': array(['ISIC_0015670', 'ISIC_0015845', 'ISIC_0015864', ...,
#           'ISIC_9999960', 'ISIC_9999964', 'ISIC_9999967'], dtype=object),
#    'metadata': array([[ 2.02444223e+01,  1.62619752e+01,  2.69224474e+01, ...,
#            -1.82703552e+02,  6.13493652e+02, -4.24279480e+01],
#           [ 3.17125700e+01,  2.53647400e+01,  2.63310000e+01, ...,
#            -7.83081100e-02,  1.57568700e+03,  5.71745000e+01],
#           [ 2.25758300e+01,  1.71281700e+01,  3.79704600e+01, ...,
#             1.23649700e+02,  1.47201000e+03,  2.32908900e+02],
#           ...,
#           [ 1.73325667e+01,  1.23643974e+01,  2.98453261e+01, ...,
#             5.46222458e+01,  1.06526367e+03, -1.06833740e+02],
#           [ 2.22885700e+01,  9.56472100e+00,  2.84312000e+01, ...,
#            -9.86155700e+00,  8.77527000e+02, -7.69821200e+01],
#           [ 1.67929000e+01,  1.14347300e+01,  2.14572200e+01, ...,
#            -2.58872300e+02,  1.48606200e+02,  1.07710600e+02]]),
#    'target': array([0, 0, 0, ..., 0, 0, 0])},
#   'val': {'isic_id': array(['ISIC_0015902', 'ISIC_0052122', 'ISIC_0067881', ...,
#           'ISIC_9999435', 'ISIC_9999883', 'ISIC_9999937'], dtype=object),
#    'metadata': array([[  14.24232888,   12.16475727,   21.44814427, ..., -141.02478027,
#            1442.18579102,   58.35980225],
#           [  23.08269749,   14.60248882,   25.37146812, ...,  -17.51486778,
#            1117.23242188,  -54.20031738],
#           [  21.81350499,   12.93459877,   32.37266509, ...,  336.32037354,
#            1402.12365723,  147.76226807],
#           ...,
#           [  15.32358848,   14.65208201,   23.52431721, ..., -267.21929932,
#            1064.46020508,   28.69293213],
#           [  19.07549456,   10.66279573,   22.22354643, ...,  189.08734131,
#            1022.27984619,   51.72723389],
#           [  22.5743346 ,   14.94466632,   27.66325866, ...,  147.18725586,
#            1182.31750488,  122.65258789]]),
#    'target': array([0, 0, 0, ..., 0, 0, 0])}},
#  '10': {'train': {'isic_id': array(['ISIC_0015670', 'ISIC_0015845', 'ISIC_0015864', ...,
#           'ISIC_9999951', 'ISIC_9999960', 'ISIC_9999967'], dtype=object),
#    'metadata': array([[ 2.02444223e+01,  1.62619752e+01,  2.69224474e+01, ...,
#            -1.82703552e+02,  6.13493652e+02, -4.24279480e+01],
#           [ 3.17125700e+01,  2.53647400e+01,  2.63310000e+01, ...,
#            -7.83081100e-02,  1.57568700e+03,  5.71745000e+01],
#           [ 2.25758300e+01,  1.71281700e+01,  3.79704600e+01, ...,
#             1.23649700e+02,  1.47201000e+03,  2.32908900e+02],
#           ...,
#           [ 1.99776400e+01,  1.60268700e+01,  3.41588400e+01, ...,
#             5.23497400e+01,  1.39318700e+03,  1.27261700e+02],
#           [ 1.73325667e+01,  1.23643974e+01,  2.98453261e+01, ...,
#             5.46222458e+01,  1.06526367e+03, -1.06833740e+02],
#           [ 1.67929000e+01,  1.14347300e+01,  2.14572200e+01, ...,
#            -2.58872300e+02,  1.48606200e+02,  1.07710600e+02]]),
#    'target': array([0, 0, 0, ..., 0, 0, 0])},
#   'val': {'isic_id': array(['ISIC_0051896', 'ISIC_0061318', 'ISIC_0071852', ...,
#           'ISIC_9999852', 'ISIC_9999919', 'ISIC_9999964'], dtype=object),
#    'metadata': array([[  22.16881   ,   18.87471   ,   31.36237   , ...,  328.5996    ,
#            1189.842     , -103.5305    ],
#           [  19.26855171,   13.45672897,   24.98201507, ...,  170.70458984,
#             790.07128906,  122.38220215],
#           [  24.88019   ,    9.363491  ,   21.68469   , ...,  167.0849    ,
#             995.8899    ,  -49.68069   ],
#           ...,
#           [  16.40038826,   14.15025685,   22.45245492, ...,  -99.68707275,
#            1261.00512695,   78.47039795],
#           [  17.95485929,   14.18464876,   26.89150082, ...,  129.81777954,
#            1521.30065918,    9.83349609],
#           [  22.28857   ,    9.564721  ,   28.4312    , ...,   -9.861557  ,
#             877.527     ,  -76.98212   ]]),
#    'target': array([0, 0, 0, ..., 0, 0, 0])}}}

# %% [markdown]
# # K - Folds

# %%
from PIL import Image
import os
import copy
import shutil
from tqdm.auto import tqdm
import albumentations as A
import numpy as np


augmentation_oversampling = A.Compose([
    # crop border avois multiple instances
    A.RandomCrop(width=config.get_value("IMAGE_WIDTH"), height=config.get_value("IMAGE_HEIGHT"), p=1),
    A.Rotate(limit=(-360, 360), p=0.50, crop_border=False),
    A.VerticalFlip(p=0.25),
    A.HorizontalFlip(p=0.25),
    A.RandomBrightnessContrast(p=0.5),
    # water reflexion effect magnification and min
    A.GridDistortion(p=0.25),
    # A.Resize(height=config.get_value("IMAGE_HEIGHT"), width=config.get_value("IMAGE_WIDTH"))
], p = 1)

dataset_path = config.get_value("DATASET_PATH")
shutil.rmtree(os.path.join(dataset_path, "splits"), ignore_errors=True)

train_metadata = []
val_metadata = []

image_source_path = config.get_value("TRAIN_IMAGES_PATH")
for fold_index in tqdm(folds_config_dict.keys()):
    print(f"Fold: {fold_index}")
    
    os.makedirs(os.path.join(dataset_path, "splits", f"fold_{fold_index}", "train", "0"), exist_ok=True)
    os.makedirs(os.path.join(dataset_path, "splits", f"fold_{fold_index}", "train", "1"), exist_ok=True)
    os.makedirs(os.path.join(dataset_path, "splits", f"fold_{fold_index}", "val", "0"), exist_ok=True)
    os.makedirs(os.path.join(dataset_path, "splits", f"fold_{fold_index}", "val", "1"), exist_ok=True)
    
    normal_images_ids = folds_config_dict[fold_index]["train"]["isic_id"][np.where(folds_config_dict[fold_index]["train"]["target"]==0)]
    anomaly_images_ids = folds_config_dict[fold_index]["train"]["isic_id"][np.where(folds_config_dict[fold_index]["train"]["target"]==1)]
    
    print(f"total images: {len(normal_images_ids) + len(anomaly_images_ids)}")
    print("Over and under sampling...")
    over_under_sample(normal_images_ids=normal_images_ids,
                      anomaly_images_ids=anomaly_images_ids,
                      augmentation_transform=augmentation_oversampling,
                      root_path=os.path.join(dataset_path, "splits", f"fold_{fold_index}"),
                      config=config)
    
    print("Saving validation images to disk...")
    for isic_id, target in tqdm(zip(folds_config_dict[fold_index]["val"]["isic_id"], folds_config_dict[fold_index]["val"]["target"]), total=len(folds_config_dict[fold_index]["val"]["isic_id"])):
        img = copy.deepcopy(Image.open(os.path.join(image_source_path, f"{isic_id}.jpg")))
        img.save(os.path.join(dataset_path, "splits", f"fold_{fold_index}", "val", f"{int(target)}", f"{isic_id}.jpg"))
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Fold: 1
# total images: 360953
# Over and under sampling...
# Target: Normal samples count: 216572 | Target: Anomally samples count: 144382
# Iterations needed to reach target count for anomaly samples: 408 | Anomaly original count: 354
#   0%|          | 0/408 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 42
#      40 print(f"total images: {len(normal_images_ids) + len(anomaly_images_ids)}")
#      41 print("Over and under sampling...")
# ---> 42 over_under_sample(normal_images_ids=normal_images_ids,
#      43                   anomaly_images_ids=anomaly_images_ids,
#      44                   augmentation_transform=augmentation_oversampling,
#      45                   root_path=os.path.join(dataset_path, "splits", f"fold_{fold_index}"),
#      46                   config=config)
#      48 print("Saving validation images to disk...")
#      49 for isic_id, target in tqdm(zip(folds_config_dict[fold_index]["val"]["isic_id"], folds_config_dict[fold_index]["val"]["target"]), total=len(folds_config_dict[fold_index]["val"]["isic_id"])):
#
# File ~/workspace/ISIC-2024-Skin-Cancer-Detection-3D-TBP/prototypes/deeplearning/dataloader/IsicDataLoader.py:206, in over_under_sample(anomaly_images_ids, normal_images_ids, augmentation_transform, root_path, config)
#     200 for suffix_index, image_id in enumerate(anomaly_images_ids):
#     201     sample_image = copy.deepcopy(Image.open(os.path.join(config.get_value("TRAIN_IMAGES_PATH"), image_id+".jpg")
#     202                                             ).resize((config.get_value("IMAGE_WIDTH"),
#     203                                                       config.get_value("IMAGE_HEIGHT")))
#     204                                  )
# --> 206     augmented_image = augmentation_transform(image=np.array(sample_image))['image']
#     207     image_buffer[:, :, suffix_index] = copy.deepcopy(augmented_image)
#     209 for suffix_index, mixed in enumerate(zip(mixup_data(image_buffer, ids=anomaly_images_ids, alpha=1.2))):
#
# ValueError: could not broadcast input array from shape (128,128,3) into shape (354,128,3)

# %%
import glob
import os

# %%
fold_index = 1

dataset_path = config.get_value("DATASET_PATH")

root = os.path.join(dataset_path, "splits", f"fold_{fold_index}", "train")

file_list = glob.glob(os.path.join(root, "*.jpg"))

# %%
os.listdir(root)

# %%
file_list[:5]

# %%
dataloader = IsicDataLoaderFolders(root=root)

# %%
next(iter(dataloader))
